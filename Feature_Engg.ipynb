# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunpanda001/EDA/blob/main/Feature_Engg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=15B0YXLJhx41faA2rVyifWMjlmpuFqAxc -O loan.csv
# Out:
# --2025-08-22 14:27:22--  https://drive.google.com/uc?id=15B0YXLJhx41faA2rVyifWMjlmpuFqAxc
# Resolving drive.google.com (drive.google.com)... 142.251.183.101, 142.251.183.139, 142.251.183.102, ...
# Connecting to drive.google.com (drive.google.com)|142.251.183.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=15B0YXLJhx41faA2rVyifWMjlmpuFqAxc [following]
# --2025-08-22 14:27:22--  https://drive.usercontent.google.com/download?id=15B0YXLJhx41faA2rVyifWMjlmpuFqAxc
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 209.85.145.132, 2607:f8b0:4001:c1e::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|209.85.145.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38011 (37K) [application/octet-stream]
# Saving to: ‘loan.csv’
#
# loan.csv            100%[===================>]  37.12K  --.-KB/s    in 0s
#
# ...

# %%
#importing Libarires
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("loan.csv")
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data["Dependents"].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
data=data.drop("Loan_ID",axis=1)

# %%
data.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.describe(include=["object"])
# Out:
#        Gender Married Dependents Education Self_Employed Property_Area  \
# count     601     611        599       614           582           614
# unique      2       2          4         2             2             3
# top      Male     Yes          0  Graduate            No     Semiurban
# freq      489     398        345       480           500           233
#
#        Loan_Status
# count          614
# unique           2
# top              Y
# freq           422

# %%
data.isna().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
(data.isna().sum()/data.shape[0])*100
# Out:
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
cat_cols=data.dtypes=="object"
cat_cols=list(cat_cols[cat_cols].index)
cat_cols
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
cat_cols.remove("Loan_Status")
cat_cols
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area']

# %%
num_cols=data.dtypes!="object"
num_cols=list(num_cols[num_cols].index)
num_cols
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
plt.rcParams["figure.figsize"] = [15,10]
data.plot(kind = 'density', subplots = True, layout = (3,3), sharex = False)
plt.show()

# %%
data.select_dtypes(include='number').skew()
# Out:
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.677552
# Loan_Amount_Term    -2.362414
# Credit_History      -1.882361
# dtype: float64

# %%
data["ApplicantIncome"].plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
data["ApplicantIncome"].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
data.select_dtypes(include='number').kurt()
# Out:
# ApplicantIncome      60.540676
# CoapplicantIncome    84.956384
# LoanAmount           10.401533
# Loan_Amount_Term      6.673474
# Credit_History        1.548763
# dtype: float64

# %% [markdown]
# UVA

# %%
data["Loan_Status"].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [6,4]
sns.countplot(data=data,x="Loan_Status")
plt.show()

# %%
plt.subplot(121)
sns.histplot(data["ApplicantIncome"], kde=True)

plt.subplot(122)
data["ApplicantIncome"].plot.box(figsize=(16,5))
plt.show()

# %%
data.groupby("Loan_Status")['ApplicantIncome'].mean()
# Out:
# Loan_Status
# N    5446.078125
# Y    5384.068720
# Name: ApplicantIncome, dtype: float64

# %%
from scipy.stats import ttest_ind

a = data[data["Loan_Status"]=="Y"]["ApplicantIncome"]
b = data[data["Loan_Status"]=="N"]["ApplicantIncome"]

# H0: Income and Loan status are independent
# Ha: Dependent
stat,p_value=ttest_ind(a, b)
p_value
# Out:
# np.float64(0.907287812130518)

# %%
alpha=0.05
if p_value<alpha:
  print("Reject H0")
else:
  print("Fail to reject H0")
# Out:
# Fail to reject H0

# %%
data["TotalIncome"] = data["ApplicantIncome"] + data["CoapplicantIncome"]

# %%
data.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  TotalIncome
# 0         Urban           Y       5849.0
# ...

# %%
bins = [0,3000,5000,8000,81000]
group = ['Low','Average','High','Very High']
data["TotalIncome_bin"] = pd.cut(data["TotalIncome"],bins,labels=group)

# %%
vals = pd.crosstab(data["TotalIncome_bin"], data["Loan_Status"])
vals
# Out:
# Loan_Status       N    Y
# TotalIncome_bin
# Low              20   27
# Average          69  154
# High             61  151
# Very High        42   90

# %%
vals_n = pd.crosstab(data["TotalIncome_bin"], data["Loan_Status"], normalize="index")
vals_n.plot(kind="bar",figsize=(4,4))
# Out:
# <Axes: xlabel='TotalIncome_bin'>

# %%
data.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  TotalIncome TotalIncome_bin
# 0         Urban           Y       5849.0            High
# ...

# %%
missing_value=pd.DataFrame({
    "Mising_Value":data.isna().sum(),
    "Percentage":(data.isna().sum()/len(data))*100
})

missing_value.sort_values(by="Percentage",ascending=False)
# Out:
#                    Mising_Value  Percentage
# Credit_History               50    8.143322
# Self_Employed                32    5.211726
# LoanAmount                   22    3.583062
# Dependents                   15    2.442997
# Loan_Amount_Term             14    2.280130
# Gender                       13    2.117264
# Married                       3    0.488599
# Education                     0    0.000000
# ApplicantIncome               0    0.000000
# CoapplicantIncome             0    0.000000
# Property_Area                 0    0.000000
# Loan_Status                   0    0.000000
# TotalIncome                   0    0.000000
# TotalIncome_bin               0    0.000000

# %%
data["Dependents"].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
data["Dependents"].replace("3+",3,inplace=True)

# %%
data["Dependents"].value_counts()
# Out:
# Dependents
# 0    345
# 1    102
# 2    101
# 3     51
# Name: count, dtype: int64

# %%
data["Credit_History"].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
a = pd.DataFrame([10, 10, 20, 10, 30, 10, np.nan, 50])
a
# Out:
#       0
# 0  10.0
# 1  10.0
# 2  20.0
# 3  10.0
# 4  30.0
# 5  10.0
# 6   NaN
# 7  50.0

# %%
a.mean()
# Out:
# 0    20.0
# dtype: float64

# %%
SimpleImputer(strategy="mean").fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [20.],
#        [50.]])

# %%
from sklearn.impute import SimpleImputer
a = pd.DataFrame([10, 10, 20, 10, 30, 10, np.nan, 50])
a
# Out:
#       0
# 0  10.0
# 1  10.0
# 2  20.0
# 3  10.0
# 4  30.0
# 5  10.0
# 6   NaN
# 7  50.0

# %%
SimpleImputer(strategy="most_frequent").fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [10.],
#        [50.]])

# %%
from sklearn.impute import SimpleImputer
a = pd.DataFrame([10, 10, 20, 10, 30, 10, np.nan, 50])
SimpleImputer(strategy="median").fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [10.],
#        [50.]])

# %%
from sklearn.impute import SimpleImputer
a = pd.DataFrame([10, 10, 20, 10, 30, 10, np.nan, 50])
SimpleImputer(strategy="constant", fill_value=1000).fit_transform(a)
# Out:
# array([[  10.],
#        [  10.],
#        [  20.],
#        [  10.],
#        [  30.],
#        [  10.],
#        [1000.],
#        [  50.]])

# %%
data.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'TotalIncome_bin'],
#       dtype='object')

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1JR9TDe1BQN9crA5n6JrL_clnNY1AhebJ -O updated_loan.csv
# Out:
# --2025-08-22 14:43:06--  https://drive.google.com/uc?id=1JR9TDe1BQN9crA5n6JrL_clnNY1AhebJ
# Resolving drive.google.com (drive.google.com)... 142.251.183.138, 142.251.183.102, 142.251.183.101, ...
# Connecting to drive.google.com (drive.google.com)|142.251.183.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JR9TDe1BQN9crA5n6JrL_clnNY1AhebJ [following]
# --2025-08-22 14:43:06--  https://drive.usercontent.google.com/download?id=1JR9TDe1BQN9crA5n6JrL_clnNY1AhebJ
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 209.85.145.132, 2607:f8b0:4001:c1e::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|209.85.145.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67001 (65K) [application/octet-stream]
# Saving to: ‘updated_loan.csv’
#
# updated_loan.csv    100%[===================>]  65.43K  --.-KB/s    in 0s
#
# ...

# %%
data=pd.read_csv("updated_loan.csv")
data.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN              30.0             1.0
# 1             1508.0       128.0              30.0             1.0
# 2                0.0        66.0              30.0             1.0
# 3             2358.0       120.0              30.0             1.0
# 4                0.0       141.0              30.0             1.0
#
#   Property_Area Loan_Status Income_bin  TotalIncome TotalIncome_bin  \
# ...

# %%
num_missing=['EMI', 'Loan_Amount_per_year',  'LoanAmount',  'Loan_Amount_Term']
median_imputer=SimpleImputer(strategy="median")
data[num_missing]=median_imputer.fit_transform(data[num_missing])

# %%
cat_missing = ['Gender', 'Married','Dependents']
freq_imputer=SimpleImputer(strategy="most_frequent")
data[cat_missing]=freq_imputer.fit_transform(data[cat_missing])

# %%
data.isna().sum()
# Out:
# Gender                   0
# Married                  0
# Dependents               0
# Education                0
# Self_Employed           32
# ApplicantIncome          0
# CoapplicantIncome        0
# LoanAmount               0
# Loan_Amount_Term         0
# Credit_History          50
# Property_Area            0
# Loan_Status              0
# Income_bin               0
# TotalIncome              0
# TotalIncome_bin          0
# Loan_Amount_per_year     0
# EMI                      0
# Able_to_pay_EMI          0
# dtype: int64

# %%
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df = pd.DataFrame({'Age': [12, 24, 25, 30, 44, 32, None, 56, 68, 28, None, 98, 43, 52, 63, 69, 86]})
from sklearn.impute import SimpleImputer
SimpleImputer(strategy="median").fit_transform(df)
# Out:
# array([[12.],
#        [24.],
#        [25.],
#        [30.],
#        [44.],
#        [32.],
#        [44.],
#        [56.],
#        [68.],
#        [28.],
#        [44.],
#        [98.],
#        [43.],
#        [52.],
#        [63.],
#        [69.],
#        [86.]])

# %% [markdown]
# ## Outlier Treatment

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                614 non-null    object
#  1   Married               614 non-null    object
#  2   Dependents            614 non-null    object
#  3   Education             614 non-null    object
#  4   Self_Employed         582 non-null    object
#  5   ApplicantIncome       614 non-null    int64
#  6   CoapplicantIncome     614 non-null    float64
#  7   LoanAmount            614 non-null    float64
#  8   Loan_Amount_Term      614 non-null    float64
#  9   Credit_History        564 non-null    float64
#  10  Property_Area         614 non-null    object
#  11  Loan_Status           614 non-null    object
#  12  Income_bin            614 non-null    object
#  13  TotalIncome           614 non-null    float64
#  14  TotalIncome_bin       614 non-null    object
# ...

# %%
data["Income_bin"]=data["Income_bin"].astype("object")
data['TotalIncome_bin'] = data['TotalIncome_bin'].astype('object')

# %%
df_num = data.select_dtypes(include = np.number)
df_num.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'TotalIncome',
#        'Loan_Amount_per_year', 'EMI', 'Able_to_pay_EMI'],
#       dtype='object')

# %% [markdown]
# IQR - Interquartile range

# %%
Q1=df_num.quantile(0.25)
Q3=df_num.quantile(0.70)
IQR=Q3-Q1
print(IQR)
# Out:
# ApplicantIncome         2308.100000
# CoapplicantIncome       2083.000000
# LoanAmount                54.750000
# Loan_Amount_Term           0.000000
# Credit_History             0.000000
# TotalIncome             2621.200000
# Loan_Amount_per_year       1.900000
# EMI                      158.333333
# Able_to_pay_EMI            0.000000
# dtype: float64

# %%
numeric_data=data.select_dtypes(include="number")
Q1=numeric_data.quantile(0.25)
Q3=numeric_data.quantile(0.75)
IQR=Q3-Q1
df_iqr=data[~((numeric_data<(Q1-1.5*IQR))|(numeric_data>(Q3+1/5*IQR))).any(axis=1)]

# %%
df_iqr.shape
# Out:
# (265, 18)

# %%
data.shape
# Out:
# (614, 18)

# %%
sns.histplot(df_iqr["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %% [markdown]
# Categorical to Numerical

# %%
df_iqr.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
# 6   Male     Yes          0  Not Graduate            No             2333
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0              30.0             1.0
# 2                0.0        66.0              30.0             1.0
# 3             2358.0       120.0              30.0             1.0
# 4                0.0       141.0              30.0             1.0
# 6             1516.0        95.0              30.0             1.0
#
#   Property_Area Loan_Status Income_bin  TotalIncome TotalIncome_bin  \
# ...

# %%
num=df_iqr.select_dtypes(include="number")
num.drop(['Able_to_pay_EMI','Credit_History'],axis=1,inplace=True)
num.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0              30.0
# 2             3000                0.0        66.0              30.0
# 3             2583             2358.0       120.0              30.0
# 4             6000                0.0       141.0              30.0
# 6             2333             1516.0        95.0              30.0
#
#    TotalIncome  Loan_Amount_per_year         EMI
# 1       6091.0              4.266667  355.555556
# 2       3000.0              2.200000  183.333333
# 3       4941.0              4.000000  333.333333
# 4       6000.0              4.700000  391.666667
# 6       3849.0              3.166667  263.888889

# %%
cat = df_iqr.select_dtypes(include=['object'])
cat.drop('Loan_Status',axis=1,inplace=True)
cat['Able_to_pay_EMI'] = df_iqr['Able_to_pay_EMI']
cat['Credit_History'] = df_iqr['Credit_History']
cat.head()
# Out:
#   Gender Married Dependents     Education Self_Employed Property_Area  \
# 1   Male     Yes          1      Graduate            No         Rural
# 2   Male     Yes          0      Graduate           Yes         Urban
# 3   Male     Yes          0  Not Graduate            No         Urban
# 4   Male      No          0      Graduate            No         Urban
# 6   Male     Yes          0  Not Graduate            No         Urban
#
#   Income_bin TotalIncome_bin  Able_to_pay_EMI  Credit_History
# 1     Medium            High                1             1.0
# 2    Average             Low                1             1.0
# 3    Average         Average                1             1.0
# 4     Medium            High                1             1.0
# 6        Low         Average                1             1.0

# %%
#OHE
pd.get_dummies(cat["Gender"])
# Out:
#      Female   Male
# 1     False   True
# 2     False   True
# 3     False   True
# 4     False   True
# 6     False   True
# ..      ...    ...
# 602   False   True
# 606   False   True
# 607   False   True
# 608   False   True
# 609    True  False
#
# [265 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat["Gender"]=le.fit_transform(cat["Gender"])

# %%
from sklearn.impute import SimpleImputer
SimpleImputer(strategy="mean").fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [20.],
#        [50.]])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat["Gender"]=le.fit_transform(cat["Gender"])
cat["Gender"]
# Out:
# 1      1
# 2      1
# 3      1
# 4      1
# 6      1
#       ..
# 602    1
# 606    1
# 607    1
# 608    1
# 609    0
# Name: Gender, Length: 265, dtype: int64

# %%
cat.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Income_bin', 'TotalIncome_bin', 'Able_to_pay_EMI',
#        'Credit_History'],
#       dtype='object')

# %%
cat["Married"].value_counts()
# Out:
# Married
# Yes    165
# No     100
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat["Married"]=le.fit_transform(cat["Married"])
cat["Married"].value_counts()
# Out:
# Married
# 1    165
# 0    100
# Name: count, dtype: int64

# %%
# !pip install --upgrade category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.3 MB/s eta 0:00:00
# ...

# %%
from category_encoders import TargetEncoder

# %%
pd.crosstab(df_iqr["Property_Area"],df_iqr["Loan_Status"])
# Out:
# Loan_Status     N   Y
# Property_Area
# Rural          22  54
# Semiurban       7  99
# Urban          18  65

# %%
col="Property_Area"
te=TargetEncoder()
df_iqr[col]=te.fit_transform(df_iqr[col],df_iqr["Loan_Status"])
df_iqr[col].value_counts()
# Out:
# Property_Area
# 0.933942    106
# 0.783205     83
# 0.710939     76
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
std_sc=StandardScaler()
num["scaled_loanammount"]=std_sc.fit_transform(num[["LoanAmount"]])

# %%
plt.rcParams["figure.figsize"]=[15,8]
plt.subplot(1,2,1)
sns.distplot(num["LoanAmount"])
plt.xlabel("Denisty",fontsize=15)
plt.ylabel("LoanAmount",fontsize=15)

plt.subplot(1,2,2)
sns.distplot(num["scaled_loanammount"])
plt.xlabel("Denisty",fontsize=15)
plt.ylabel("scaled_loanammount",fontsize=15)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
num['minmax_LoanAmount'] = min_max.fit_transform(num[['LoanAmount']])
